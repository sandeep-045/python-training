# %%
# !pip install pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached Pillow-8.2.0.tar.gz (47.9 MB)
# ...
#   ERROR: Command errored out with exit status 1:
#    command: /Library/Developer/CommandLineTools/usr/bin/python3 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/4q/kz14h8396jbd_xx21dm3ky9w0000gn/T/pip-install-jgd7fa4u/pillow_c29b3da3e5454ede8b32069aa376987e/setup.py'"'"'; __file__='"'"'/private/var/folders/4q/kz14h8396jbd_xx21dm3ky9w0000gn/T/pip-install-jgd7fa4u/pillow_c29b3da3e5454ede8b32069aa376987e/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/4q/kz14h8396jbd_xx21dm3ky9w0000gn/T/pip-wheel-3rhccf6p
# ...

# %%
from PIL import Image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-b7f01c2f8cfe> in <module>
# ----> 1 from PIL import Image
#
# ModuleNotFoundError: No module named 'PIL'
