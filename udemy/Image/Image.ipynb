# %%
from PIL import Image

# %%
s=Image.open('example.jpg')

# %%
s.size
# Out:
# (1993, 1257)

# %%
s.filename
# Out:
# 'example.jpg'

# %%
s.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
halfway=1993/2

# %%
y = 800
h = 1257

# %%
x = halfway - 200
w = halfway + 200

# %%
cter=s.crop((x,y,w,h))

# %%
cter
# Out:
# <PIL.Image.Image image mode=RGB size=400x457 at 0x11C34D0>

# %%
s.paste(cter,(0,0))

# %%
s
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257 at 0x1184590>

# %%
s.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=1993x1257 at 0x74DA970>

# %%
blue=Image.open('blue_color.png').convert("RGBA")

# %%
red=Image.open('red_color.jpg').convert("RGBA")

# %%
blue.putalpha(120)

# %%
red.putalpha(120)

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=200x200 at 0x75FD3B0>

# %%
red.paste(blue,(0,0),blue)

# %%
red
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x7C90FF0>

# %%
red.save("purpl.png")
